# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

from analysis_toolkit import setup_latex, util, plots
from analysis_toolkit import definitions as defs

summary = pd.read_csv('summary.csv', dtype=defs.COLUMNS)
setup_latex()

# %%
FIG_TEXT = r"""
\begin{{figure}}[H]
    \centering
    \includegraphics[width=0.8\textwidth]{{plots/p1_{plot}_{metric}/d={d},p={p},k={k}.pdf}}
    \caption{{{metric_desc} | {d} Dimensions, {k} Clusters ({p} Points) | {plot_desc}}}
    \label{{fig:{metric}_d{d}_k{k}_{plot}}}
\end{{figure}}"""

for d, k in [(3, 3), (3, 5), (3, 8), (5, 3), (8, 3)]:
    for metric, metric_desc in [('rand', 'Oracle Normalized Rand Score'), ('nmi', 'Oracle Normalized NMI')]:
        for plot, desc in [('boxplot', 'Boxplot of 100 Runs'), ('se', '2SE Intervals; arrow denotes intervals less than 0.8')]:
            print(FIG_TEXT.format(
                d=d, k=k, p=d * k * 80, plot=plot,
                metric=metric, metric_desc=metric_desc, plot_desc=desc))
# Out:
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_rand/d=3,p=720,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 3 Clusters (720 Points) | Boxplot of 100 Runs}
#     \label{fig:rand_d3_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_rand/d=3,p=720,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 3 Clusters (720 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:rand_d3_k3_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_nmi/d=3,p=720,k=3.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 3 Clusters (720 Points) | Boxplot of 100 Runs}
#     \label{fig:nmi_d3_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_nmi/d=3,p=720,k=3.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 3 Clusters (720 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:nmi_d3_k3_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_rand/d=3,p=1200,k=5.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 5 Clusters (1200 Points) | Boxplot of 100 Runs}
#     \label{fig:rand_d3_k5_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_rand/d=3,p=1200,k=5.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 5 Clusters (1200 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:rand_d3_k5_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_nmi/d=3,p=1200,k=5.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 5 Clusters (1200 Points) | Boxplot of 100 Runs}
#     \label{fig:nmi_d3_k5_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_nmi/d=3,p=1200,k=5.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 5 Clusters (1200 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:nmi_d3_k5_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_rand/d=3,p=1920,k=8.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 8 Clusters (1920 Points) | Boxplot of 100 Runs}
#     \label{fig:rand_d3_k8_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_rand/d=3,p=1920,k=8.pdf}
#     \caption{Oracle Normalized Rand Score | 3 Dimensions, 8 Clusters (1920 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:rand_d3_k8_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_nmi/d=3,p=1920,k=8.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 8 Clusters (1920 Points) | Boxplot of 100 Runs}
#     \label{fig:nmi_d3_k8_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_nmi/d=3,p=1920,k=8.pdf}
#     \caption{Oracle Normalized NMI | 3 Dimensions, 8 Clusters (1920 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:nmi_d3_k8_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_rand/d=5,p=1200,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 5 Dimensions, 3 Clusters (1200 Points) | Boxplot of 100 Runs}
#     \label{fig:rand_d5_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_rand/d=5,p=1200,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 5 Dimensions, 3 Clusters (1200 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:rand_d5_k3_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_nmi/d=5,p=1200,k=3.pdf}
#     \caption{Oracle Normalized NMI | 5 Dimensions, 3 Clusters (1200 Points) | Boxplot of 100 Runs}
#     \label{fig:nmi_d5_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_nmi/d=5,p=1200,k=3.pdf}
#     \caption{Oracle Normalized NMI | 5 Dimensions, 3 Clusters (1200 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:nmi_d5_k3_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_rand/d=8,p=1920,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 8 Dimensions, 3 Clusters (1920 Points) | Boxplot of 100 Runs}
#     \label{fig:rand_d8_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_rand/d=8,p=1920,k=3.pdf}
#     \caption{Oracle Normalized Rand Score | 8 Dimensions, 3 Clusters (1920 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:rand_d8_k3_se}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_boxplot_nmi/d=8,p=1920,k=3.pdf}
#     \caption{Oracle Normalized NMI | 8 Dimensions, 3 Clusters (1920 Points) | Boxplot of 100 Runs}
#     \label{fig:nmi_d8_k3_boxplot}
# \end{figure}
#
# \begin{figure}[H]
#     \centering
#     \includegraphics[width=0.8\textwidth]{plots/p1_se_nmi/d=8,p=1920,k=3.pdf}
#     \caption{Oracle Normalized NMI | 8 Dimensions, 3 Clusters (1920 Points) | 2SE Intervals; arrow denotes intervals less than 0.8}
#     \label{fig:nmi_d8_k3_se}
# \end{figure}

# %%
def stats_table(key):
    res = [
        '\hline',
        '$(d, k)$ & {} \\\\'.format(
            ' & '.join([
                '$({}, {})$'.format(t['d'], t['k'])
                for t in defs.TESTS_P1
            ])),
        '\hline'
    ]

    for method, desc in defs.METHODS_P1.items():
        data = [util.oracle_ratio(summary, key=key, method=method, **t) for t in defs.TESTS_P1]

        body = ' & '.join([
            "${:.3f} \pm {:.3f}$".format(np.mean(d), 2 * stats.sem(d)) for d in data])
        res.append('{} & {} \\\\'.format(desc, body))

    res.append('\hline')
    res.insert(10, '\hline')
    return '\n'.join(res)

# %%
print(stats_table('rand'))
# Out:
# \hline
# $(d, k)$ & $(3, 3)$ & $(3, 5)$ & $(3, 8)$ & $(5, 3)$ & $(8, 3)$ \\
# \hline
# MFM: poisson$(k + 2)$ & $0.949 \pm 0.015$ & $0.936 \pm 0.013$ & $0.938 \pm 0.009$ & $0.983 \pm 0.004$ & $0.994 \pm 0.002$ \\
# MFM: (5,1) hybrid & $0.958 \pm 0.011$ & $0.939 \pm 0.011$ & $0.938 \pm 0.009$ & $0.981 \pm 0.007$ & $0.994 \pm 0.002$ \\
# MFM: poisson$(k - 2)$ & $0.964 \pm 0.010$ & $0.943 \pm 0.010$ & $0.940 \pm 0.007$ & $0.982 \pm 0.006$ & $0.994 \pm 0.002$ \\
# MFM: gibbs & $0.925 \pm 0.032$ & $0.881 \pm 0.035$ & $0.885 \pm 0.033$ & $0.808 \pm 0.056$ & $0.018 \pm 0.020$ \\
# MFM: split merge & $0.718 \pm 0.030$ & $0.670 \pm 0.028$ & $0.663 \pm 0.028$ & $0.742 \pm 0.034$ & $0.873 \pm 0.015$ \\
# MFM: (3,1) hybrid & $0.955 \pm 0.012$ & $0.939 \pm 0.011$ & $0.939 \pm 0.008$ & $0.978 \pm 0.010$ & $0.995 \pm 0.002$ \\
# MFM: (10,1) hybrid & $0.961 \pm 0.010$ & $0.941 \pm 0.010$ & $0.939 \pm 0.009$ & $0.983 \pm 0.005$ & $0.994 \pm 0.002$ \\
# \hline
# DPM: $\alpha=0.1$ & $0.963 \pm 0.009$ & $0.943 \pm 0.010$ & $0.945 \pm 0.007$ & $0.983 \pm 0.004$ & $0.995 \pm 0.002$ \\
# DPM: (5,1) hybrid & $0.941 \pm 0.016$ & $0.935 \pm 0.011$ & $0.937 \pm 0.008$ & $0.982 \pm 0.005$ & $0.991 \pm 0.008$ \\
# DPM: $\alpha=10$ & $0.856 \pm 0.031$ & $0.891 \pm 0.017$ & $0.907 \pm 0.021$ & $0.970 \pm 0.010$ & $0.989 \pm 0.009$ \\
# DPM: split merge & $0.609 \pm 0.028$ & $0.640 \pm 0.025$ & $0.664 \pm 0.028$ & $0.717 \pm 0.032$ & $0.880 \pm 0.015$ \\
# DPM: gibbs & $0.944 \pm 0.015$ & $0.937 \pm 0.011$ & $0.935 \pm 0.009$ & $0.943 \pm 0.025$ & $0.032 \pm 0.025$ \\
# DPM: EB & $0.913 \pm 0.028$ & $0.921 \pm 0.015$ & $0.923 \pm 0.012$ & $0.980 \pm 0.007$ & $0.995 \pm 0.002$ \\
# DPM: EB, gibbs & $0.921 \pm 0.025$ & $0.922 \pm 0.015$ & $0.921 \pm 0.013$ & $0.944 \pm 0.024$ & $0.028 \pm 0.023$ \\
# \hline

# %%
print(stats_table('nmi'))
# Out:
# \hline
# $(d, k)$ & $(3, 3)$ & $(3, 5)$ & $(3, 8)$ & $(5, 3)$ & $(8, 3)$ \\
# \hline
# MFM: poisson$(k + 2)$ & $0.940 \pm 0.015$ & $0.935 \pm 0.011$ & $0.939 \pm 0.007$ & $0.979 \pm 0.005$ & $0.991 \pm 0.002$ \\
# MFM: (5,1) hybrid & $0.949 \pm 0.012$ & $0.938 \pm 0.010$ & $0.937 \pm 0.008$ & $0.978 \pm 0.005$ & $0.991 \pm 0.002$ \\
# MFM: poisson$(k - 2)$ & $0.958 \pm 0.011$ & $0.943 \pm 0.010$ & $0.940 \pm 0.006$ & $0.980 \pm 0.005$ & $0.992 \pm 0.002$ \\
# MFM: gibbs & $0.922 \pm 0.031$ & $0.906 \pm 0.024$ & $0.909 \pm 0.023$ & $0.849 \pm 0.048$ & $0.023 \pm 0.025$ \\
# MFM: split merge & $0.710 \pm 0.023$ & $0.717 \pm 0.017$ & $0.725 \pm 0.015$ & $0.720 \pm 0.027$ & $0.840 \pm 0.014$ \\
# MFM: (3,1) hybrid & $0.947 \pm 0.013$ & $0.937 \pm 0.010$ & $0.939 \pm 0.007$ & $0.977 \pm 0.006$ & $0.992 \pm 0.002$ \\
# MFM: (10,1) hybrid & $0.953 \pm 0.012$ & $0.940 \pm 0.010$ & $0.940 \pm 0.008$ & $0.978 \pm 0.005$ & $0.991 \pm 0.003$ \\
# \hline
# DPM: $\alpha=0.1$ & $0.956 \pm 0.010$ & $0.945 \pm 0.009$ & $0.947 \pm 0.006$ & $0.978 \pm 0.005$ & $0.993 \pm 0.002$ \\
# DPM: (5,1) hybrid & $0.927 \pm 0.017$ & $0.932 \pm 0.010$ & $0.936 \pm 0.007$ & $0.976 \pm 0.006$ & $0.989 \pm 0.005$ \\
# DPM: $\alpha=10$ & $0.836 \pm 0.027$ & $0.882 \pm 0.015$ & $0.900 \pm 0.020$ & $0.960 \pm 0.007$ & $0.984 \pm 0.010$ \\
# DPM: split merge & $0.627 \pm 0.017$ & $0.696 \pm 0.015$ & $0.724 \pm 0.015$ & $0.685 \pm 0.026$ & $0.846 \pm 0.013$ \\
# DPM: gibbs & $0.931 \pm 0.016$ & $0.936 \pm 0.011$ & $0.937 \pm 0.007$ & $0.954 \pm 0.016$ & $0.052 \pm 0.033$ \\
# DPM: EB & $0.905 \pm 0.024$ & $0.917 \pm 0.014$ & $0.921 \pm 0.010$ & $0.976 \pm 0.005$ & $0.992 \pm 0.002$ \\
# DPM: EB, gibbs & $0.911 \pm 0.023$ & $0.920 \pm 0.014$ & $0.921 \pm 0.011$ & $0.955 \pm 0.015$ & $0.047 \pm 0.030$ \\
# \hline
